# %%
from tensorflow import keras
from tensorflow.keras import layers 
from tensorflow.keras.datasets import mnist

import numpy as np
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# 60,000 samples, each a 28x28 matrix. Each one correponds to a label 0-9
# not a lot of data, we can perform a 5-fold validation 

# randomize order of data, to obtain better distribution 
random_indices = np.random.permutation(len(train_images))
train_images = train_images[random_indices]
train_labels = train_labels[random_indices]

# pre-process data into 2D arrays, each value is from 0-1 instead of 0-255. 
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# model
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(46, activation="softmax")
])

  model.compile(optimizer="rmsprop",
                loss="sparse_categorical_crossentropy",
                metrics=["accuracy"])
  return model

k = 5
num_val_samples = len(train_images) // k 
num_epochs = 10
all_accuracy_histories = []

for i in range(k):
  print(f"Processing fold #{i+1}")
  validation_data = train_images[i * num_val_samples: (i + 1) * num_val_samples] 
  validation_labels = train_labels[i * num_val_samples: (i + 1) * num_val_samples] 

  training_data = np.concatenate(
    [train_images[:i * num_val_samples], 
    train_images[(i + 1) * num_val_samples:]],
    axis=0)
  
  training_labels = np.concatenate(
    [train_labels[:i * num_val_samples], 
      train_labels[(i + 1) * num_val_samples:]],
    axis=0)
  
  model = build_model()
 
  history = model.fit(training_data,
                      training_labels,
                      epochs=num_epochs,
                      batch_size = 32,
                      validation_data=(validation_data, validation_labels))
  
    
  accuracy_history = history.history["val_accuracy"]
  all_accuracy_histories.append(accuracy_history)

  loss_history = history.history["val_loss"]
  loss_of_model, accuracy_of_model = model.evaluate(test_images, test_labels)
  loss_history.append(loss_of_model)

print(loss_history)
print(np.mean(loss_history))

average_mae_history = [np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

truncated_mae_history = average_mae_history[10:] # first 10 skew graph
plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
plt.xlabel("Epochs")
plt.ylabel("Validation MAE")
plt.show()
# Out:
# Processing fold #1
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2241 - accuracy: 0.9336 - val_loss: 0.1316 - val_accuracy: 0.9603
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0977 - accuracy: 0.9710 - val_loss: 0.1015 - val_accuracy: 0.9715
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0689 - accuracy: 0.9802 - val_loss: 0.0962 - val_accuracy: 0.9744
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0522 - accuracy: 0.9852 - val_loss: 0.0936 - val_accuracy: 0.9763
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0395 - accuracy: 0.9889 - val_loss: 0.1094 - val_accuracy: 0.9755
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0328 - accuracy: 0.9911 - val_loss: 0.0974 - val_accuracy: 0.9768
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0262 - accuracy: 0.9927 - val_loss: 0.1076 - val_accuracy: 0.9777
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.1177 - val_accuracy: 0.9768
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0165 - accuracy: 0.9954 - val_loss: 0.1164 - val_accuracy: 0.9797
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.1219 - val_accuracy: 0.9787
# 313/313 [==============================] - 0s 595us/step - loss: 0.1119 - accuracy: 0.9785
# Processing fold #2
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2188 - accuracy: 0.9345 - val_loss: 0.1284 - val_accuracy: 0.9619
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0973 - accuracy: 0.9715 - val_loss: 0.1117 - val_accuracy: 0.9692
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0680 - accuracy: 0.9803 - val_loss: 0.1110 - val_accuracy: 0.9719
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0519 - accuracy: 0.9851 - val_loss: 0.1140 - val_accuracy: 0.9737
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0410 - accuracy: 0.9882 - val_loss: 0.1121 - val_accuracy: 0.9740
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0315 - accuracy: 0.9907 - val_loss: 0.1325 - val_accuracy: 0.9717
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.1337 - val_accuracy: 0.9754
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0220 - accuracy: 0.9941 - val_loss: 0.1203 - val_accuracy: 0.9781
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0169 - accuracy: 0.9952 - val_loss: 0.1289 - val_accuracy: 0.9778
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.1430 - val_accuracy: 0.9760
# 313/313 [==============================] - 0s 580us/step - loss: 0.1232 - accuracy: 0.9775
# Processing fold #3
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2263 - accuracy: 0.9329 - val_loss: 0.1284 - val_accuracy: 0.9636
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0989 - accuracy: 0.9713 - val_loss: 0.1020 - val_accuracy: 0.9714
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0663 - accuracy: 0.9810 - val_loss: 0.1086 - val_accuracy: 0.9725
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0517 - accuracy: 0.9854 - val_loss: 0.1025 - val_accuracy: 0.9761
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0408 - accuracy: 0.9879 - val_loss: 0.0903 - val_accuracy: 0.9801
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0324 - accuracy: 0.9909 - val_loss: 0.1009 - val_accuracy: 0.9795
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0259 - accuracy: 0.9928 - val_loss: 0.1075 - val_accuracy: 0.9787
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0214 - accuracy: 0.9938 - val_loss: 0.1187 - val_accuracy: 0.9771
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.1180 - val_accuracy: 0.9797
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.1248 - val_accuracy: 0.9798
# 313/313 [==============================] - 0s 594us/step - loss: 0.1074 - accuracy: 0.9812
# Processing fold #4
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2185 - accuracy: 0.9351 - val_loss: 0.1330 - val_accuracy: 0.9597
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0962 - accuracy: 0.9721 - val_loss: 0.0998 - val_accuracy: 0.9713
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0684 - accuracy: 0.9798 - val_loss: 0.1026 - val_accuracy: 0.9718
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0532 - accuracy: 0.9849 - val_loss: 0.0983 - val_accuracy: 0.9738
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0416 - accuracy: 0.9877 - val_loss: 0.0927 - val_accuracy: 0.9778
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0324 - accuracy: 0.9908 - val_loss: 0.1182 - val_accuracy: 0.9754
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0266 - accuracy: 0.9928 - val_loss: 0.0919 - val_accuracy: 0.9781
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.1109 - val_accuracy: 0.9787
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0166 - accuracy: 0.9954 - val_loss: 0.1085 - val_accuracy: 0.9795
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 0.1044 - val_accuracy: 0.9797
# 313/313 [==============================] - 0s 571us/step - loss: 0.1064 - accuracy: 0.9788
# Processing fold #5
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2203 - accuracy: 0.9349 - val_loss: 0.1401 - val_accuracy: 0.9596
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0986 - accuracy: 0.9707 - val_loss: 0.1054 - val_accuracy: 0.9686
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0684 - accuracy: 0.9796 - val_loss: 0.0932 - val_accuracy: 0.9752
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0522 - accuracy: 0.9850 - val_loss: 0.0956 - val_accuracy: 0.9779
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0417 - accuracy: 0.9885 - val_loss: 0.1004 - val_accuracy: 0.9771
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0337 - accuracy: 0.9906 - val_loss: 0.1118 - val_accuracy: 0.9758
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0275 - accuracy: 0.9924 - val_loss: 0.1004 - val_accuracy: 0.9799
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0221 - accuracy: 0.9939 - val_loss: 0.0965 - val_accuracy: 0.9808
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0170 - accuracy: 0.9953 - val_loss: 0.1153 - val_accuracy: 0.9793
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.1081 - val_accuracy: 0.9812
# 313/313 [==============================] - 0s 652us/step - loss: 0.1047 - accuracy: 0.9779
# [0.14005842804908752, 0.10538696497678757, 0.0931842252612114, 0.09559798985719681, 0.10037517547607422, 0.11176146566867828, 0.10038404166698456, 0.0965493842959404, 0.11528576910495758, 0.10809537768363953, 0.10465444624423981]
# 0.10648484257134525
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 74
#      71 print(loss_history)
#      72 print(np.mean(loss_history))
# ---> 74 average_mae_history = [np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]
#      76 truncated_mae_history = average_mae_history[10:] # first 10 skew graph
#      77 plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
#
# Cell In[1], line 74, in <listcomp>(.0)
#      71 print(loss_history)
#      72 print(np.mean(loss_history))
# ---> 74 average_mae_history = [np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]
#      76 truncated_mae_history = average_mae_history[10:] # first 10 skew graph
#      77 plt.plot(range(1, len(truncated_mae_history) + 1), truncated_mae_history)
#
# NameError: name 'all_mae_histories' is not defined
